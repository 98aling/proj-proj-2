# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df1 = pd.read_csv('Chapters.csv', encoding='latin-1')
df2 = pd.read_csv('WorldCupMatches.csv', encoding='latin-1')

# %%
df1.head()
df2.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# ...

# %%
df2.head()
df1.head()
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
print(df2.head())  # Display the first few rows
print(df2.info())  # Display information about the dataset
print(df2.describe())  # Display summary statistics
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# ...

# %%
# Check for missing values
print(df1.isnull().sum())
print(df2.isnull().sum())

# Handle missing values (example: fill with mean)
df1. fillna(df.mean(), inplace=True)
df2. fillna(df.mean(), inplace=True)
# Out:
# Chapter ID       0
# Chapter Name     0
# Movie ID         0
# Movie Chapter    0
# dtype: int64
# Year                    0
# Datetime                0
# Stage                   0
# Stadium                 0
# City                    0
# Home Team Name          0
# Home Team Goals         0
# Away Team Goals         0
# Away Team Name          0
# Win conditions          0
# Attendance              2
# Half-time Home Goals    0
# Half-time Away Goals    0
# Referee                 0
# Assistant 1             0
# Assistant 2             0
# RoundID                 0
# MatchID                 0
# Home Team Initials      0
# Away Team Initials      0
# dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 6
#       3 print(df2.isnull().sum())
#       5 # Handle missing values (example: fill with mean)
# ----> 6 df1. fillna(df.mean(), inplace=True)
# ...

# %%
# Example: Remove duplicates
df1 = df1.drop_duplicates()
df2 = df2.drop_duplicates()

# %%
# Check for missing values
print(chapters_data.isnull().sum())
print(worldcup_matches_data.isnull().sum())

# Handling missing values
chapters_data = chapters_data.fillna(chapters_data.mean())  # Replace missing values with mean
# Out:
# Chapter ID       0
# Chapter Name     0
# Movie ID         0
# Movie Chapter    0
# dtype: int64
# Year                    0
# Datetime                0
# Stage                   0
# Stadium                 0
# City                    0
# Home Team Name          0
# Home Team Goals         0
# Away Team Goals         0
# Away Team Name          0
# Win conditions          0
# Attendance              2
# Half-time Home Goals    0
# Half-time Away Goals    0
# Referee                 0
# Assistant 1             0
# Assistant 2             0
# RoundID                 0
# MatchID                 0
# Home Team Initials      0
# Away Team Initials      0
# dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:1680, in _ensure_numeric(x)
#    1679 try:
# -> 1680     x = x.astype(np.complex128)
# ...

# %%
# Display basic information about the DataFrame
print("Original DataFrame:")
print(df.info())
# Out:
# Original DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Chapter ID     234 non-null    int64
#  1   Chapter Name   234 non-null    object
#  2   Movie ID       234 non-null    int64
#  3   Movie Chapter  234 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 7.4+ KB
# None

# %%
# Handling missing values
# Drop rows with any missing values
df = df.dropna()

# %%
# Display information about the cleaned DataFrame
print("\nCleaned DataFrame:")
print(df.info())
# Out:
# Cleaned DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Chapter ID     234 non-null    int64
#  1   Chapter Name   234 non-null    object
#  2   Movie ID       234 non-null    int64
#  3   Movie Chapter  234 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 7.4+ KB
# None

# %%
import pandas as pd
import matplotlib.pyplot as plt



# Visualization 2: Scatter plot of World Cup match attendance
plt.scatter(df2['Year'], df2['Attendance'], color='green', alpha=0.7)
plt.title('World Cup Match Attendance Over Years')
plt.xlabel('Year')
plt.ylabel('Attendance')
plt.show()

# Visualization 3: Box plot of chapter lengths
df1['Chapter Length'] = df1['Text'].apply(len)
df1.boxplot(column='Chapter Length', vert=False, patch_artist=True, notch=True)
plt.title('Box Plot of Chapter Lengths')
plt.xlabel('Chapter Length')
plt.show()

# Visualization 4: Pie chart of goal distribution in World Cup matches
goal_types = df2['Home Team Goals'].append(df2['Away Team Goals'])
goal_types = goal_types.value_counts()
goal_types.plot(kind='pie', autopct='%1.1f%%', colors=['gold', 'lightcoral', 'lightskyblue'])
plt.title('Goal Distribution in World Cup Matches')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Text'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 14
# ...

# %%
# Visualization 2: Scatter plot of World Cup match attendance
plt.scatter(df2['Year'], df2['Attendance'], color='green', alpha=0.7)
plt.title('World Cup Match Attendance Over Years')
plt.xlabel('Year')
plt.ylabel('Attendance')
plt.show()

# %%
# Visualization 2: Scatter plot of World Cup match attendance
plt.scatter(df2['Year'], df2['Attendance'], color='green', alpha=0.7)
plt.title('World Cup Match Attendance Over Years')
plt.xlabel('Year')
plt.ylabel('Attendance')
plt.show()
